# %%
print("SR TRAVEL AGENCY")


print("Enter your travel details")

date = input("Enter Travel Date (DD/MM/YYYY): ")
trip = input("Enter Trip Type (International/Domestic): ")
duration = int(input("Enter Travel Duration (number of days): "))
budget = float(input("Enter Your Budget (in Million, e.g. 2): "))

print("AVAILABLE FLIGHTS")


if trip == "International":

    print("\n1. London")
    print("   Flight Date:", date)
    print("   Departure Time: 8:30 AM")
    print("   Travel Duration:", duration, "days")
    print("   Flight Budget: 5M")

    print("\n2. Dubai")
    print("   Flight Date:", date)
    print("   Departure Time: 2:00 PM")
    print("   Travel Duration:", duration, "days")
    print("   Flight Budget: 2M")

    print("\n3. Canada")
    print("   Flight Date:", date)
    print("   Departure Time: 6:00 PM")
    print("   Travel Duration:", duration, "days")
    print("   Flight Budget: 4M")

    print("\nYour Budget:", budget, "M")

elif trip == "Domestic":

    print("\n1. Islamabad")
    print("   Flight Date:", date)
    print("   Departure Time: 8:00 AM")
    print("   Travel Duration:", duration, "days")
    print("   Flight Budget: 0.8M")

    print("\n2. Skardu")
    print("   Flight Date:", date)
    print("   Departure Time: 5:00 PM")
    print("   Travel Duration:", duration, "days")
    print("   Flight Budget: 1M")

    print("\n3. Lahore")
    print("   Flight Date:", date)
    print("   Departure Time: 10:00 AM")
    print("   Travel Duration:", duration, "days")
    print("   Flight Budget: 0.6M")

    print("\nYour Budget:", budget, "M")

else:
    print("Invalid Trip Type")

print("\nThank you for choosing SR Travel Agency!")
# Out:
# SR TRAVEL AGENCY
# Enter your travel details
# Enter Travel Date (DD/MM/YYYY): 12/03/2026
# Enter Trip Type (International/Domestic): Domestic
# Enter Travel Duration (number of days): 25
# Enter Your Budget (in Million, e.g. 2): 3
# AVAILABLE FLIGHTS
#
# 1. Islamabad
#    Flight Date: 12/03/2026
#    Departure Time: 8:00 AM
#    Travel Duration: 25 days
#    Flight Budget: 0.8M
#
# 2. Skardu
#    Flight Date: 12/03/2026
#    Departure Time: 5:00 PM
#    Travel Duration: 25 days
#    Flight Budget: 1M
#
# 3. Lahore
#    Flight Date: 12/03/2026
#    Departure Time: 10:00 AM
#    Travel Duration: 25 days
#    Flight Budget: 0.6M
#
# Your Budget: 3.0 M
#
# Thank you for choosing SR Travel Agency!
