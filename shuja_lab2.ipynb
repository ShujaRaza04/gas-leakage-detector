# %% [markdown]
# <a href="https://colab.research.google.com/github/ShujaRaza04/gas-leakage-detector/blob/main/shuja_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 53.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.0/260.0 kB 20.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.49.0
#     Uninstalling google-auth-2.49.0:
#       Successfully uninstalled google-auth-2.49.0
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 2.12.1
#     Uninstalling google-genai-2.12.1:
#       Successfully uninstalled google-genai-2.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.57.1 which is incompatible.
# ...

# %%
from google import genai
from google.colab import userdata

api_key = userdata.get("apikey")

client = genai.Client(api_key=api_key)

while True:
    user_input = input("You: ")

    if user_input.lower() in ["bye", "quit"]:
        print("AI: Goodbye! 👋")
        break

    response = client.interactions.create(
        model="gemini-3.8-flash",
        input=user_input
    )


    print("AI:", response.output_text)
# Out:
# You: hello
# AI: Hello! How can I help you today?
